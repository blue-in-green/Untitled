# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'C:\Users\total\Desktop\Project\Untitled\aid_worker_incidents_1997_2024.csv').drop(0).dropna(subset=['Year', 'Month', 'Country'])

# %%
data
# Out:
#      Incident ID  Year Month  Day Country Code  \
# 2              1  1997     1  NaN           KH
# 3              2  1997     1  NaN           RW
# 4              3  1997     2  NaN           TJ
# 5              4  1997     2  NaN           SO
# 6              5  1997     2   14           RW
# ...          ...   ...   ...  ...          ...
# 4017        4151  2024     6   19           SD
# 4018        4172  2024     6   22           MM
# 4019        4156  2024     6   25           PS
# 4020        4180  2024     6   29           NG
# 4021        4173  2024     6   30           CD
#
#                                Country            Region  District  \
# 2                             Cambodia  Banteay Meanchey       NaN
# 3                               Rwanda          Northern   Musanze
# 4                           Tajikistan               NaN       NaN
# 5                              Somalia        Lower Juba   Kismayo
# ...

# %%
data.to_csv('data.csv', index=False)
